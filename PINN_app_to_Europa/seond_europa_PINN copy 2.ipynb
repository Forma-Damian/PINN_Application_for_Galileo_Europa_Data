# %% [markdown]
# 1. Europa as a Moon
# 2. Jupiter's Large Magnetic Field
# 3. Europa's orbit's eccentricity and changing net magnetic field
# 4. Europa's subsurface salty ocean and inducing its own magnetic field
# 5. Galileo Data
# 6. Europa Clipper and JUICE (JUpiter ICy-moon Explorer) in 2030-2031

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import copy

# %%
# data loading and presenting
orbits = ['ORB04', "ORB11", "ORB12", "ORB14", "ORB19", "ORB26"]


orbits_preproc_data = []


for i, orbit in enumerate(orbits):
    str = f"{orbits[i]}_EUR_EPHIO.csv"
    current_orbit_data = []
    df = pd.read_csv(str)

    # Inputs: X, Y, Z coordinates
    X_raw = df[['X', 'Y', 'Z']].values
    # Outputs: Magnetic Field Bx, By, Bz
    y_raw = df[['BX', 'BY', 'BZ']].values

    # Scale data to [-1, 1] for Tanh stability and easier gradient flow
    input_scaler = MinMaxScaler(feature_range=(-1, 1))
    output_scaler = MinMaxScaler(feature_range=(-1, 1))

    X_scaled = input_scaler.fit_transform(X_raw)
    y_scaled = output_scaler.fit_transform(y_raw)

    # to tensor
    X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
    y_tensor = torch.tensor(y_scaled, dtype=torch.float32)

    # data split
    X_train, X_val, y_train, y_val = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)


    current_orbit_data.append((X_raw, y_raw, X_train, y_train, X_val, y_val, input_scaler, output_scaler))
    orbits_preproc_data.append(current_orbit_data)

# print(orbits_preproc_data)  # Example: Print shape of raw inputs for first orbit

# %%
# define the model
class PINN(nn.Module):
    def __init__(self):
        super(PINN, self).__init__()
        # Standard MLP architecture
        self.net = nn.Sequential(
            nn.Linear(3, 40),
            nn.Tanh(),
            nn.Linear(40, 40),
            nn.Tanh(),
            nn.Linear(40, 40),
            nn.Tanh(),
            nn.Linear(40, 40),
            nn.Tanh(),
            nn.Linear(40, 3)  # Output: Bx, By, Bz
        )

    def forward(self, x):
        return self.net(x)

# %%
def physics_loss_function(model, x_collocation):
    """
    Calculates the residuals of Maxwell's equations at random points.
    """
    # Enable gradient tracking for the input coordinates (required for derivative)
    x_collocation.requires_grad = True

    # Predict B-field at these random points
    b_pred = model(x_collocation)

    # Separate components
    bx = b_pred[:, 0].unsqueeze(1)
    by = b_pred[:, 1].unsqueeze(1)
    bz = b_pred[:, 2].unsqueeze(1)

    # --- Compute Gradients (Automatic Differentiation) ---
    # We need d(Bi)/d(xj)

    # Gradients for Bx
    grads_bx = torch.autograd.grad(bx, x_collocation, grad_outputs=torch.ones_like(bx), create_graph=True)[0]
    dbx_dx, dbx_dy, dbx_dz = grads_bx[:, 0], grads_bx[:, 1], grads_bx[:, 2]

    # Gradients for By
    grads_by = torch.autograd.grad(by, x_collocation, grad_outputs=torch.ones_like(by), create_graph=True)[0]
    dby_dx, dby_dy, dby_dz = grads_by[:, 0], grads_by[:, 1], grads_by[:, 2]

    # Gradients for Bz
    grads_bz = torch.autograd.grad(bz, x_collocation, grad_outputs=torch.ones_like(bz), create_graph=True)[0]
    dbz_dx, dbz_dy, dbz_dz = grads_bz[:, 0], grads_bz[:, 1], grads_bz[:, 2]

    # --- Constraint 1: Divergence Free (No Monopoles) ---
    # div(B) = dBx/dx + dBy/dy + dBz/dz = 0
    divergence = dbx_dx + dby_dy + dbz_dz
    loss_div = torch.mean(divergence ** 2)

    # --- Constraint 2: Curl Free (Current Free Region) ---
    # curl(B) = 0 (assuming we are in the space above the ocean)
    curl_x = dbz_dy - dby_dz
    curl_y = dbx_dz - dbz_dx
    curl_z = dby_dx - dbx_dy
    loss_curl = torch.mean(curl_x**2 + curl_y**2 + curl_z**2)

    return loss_div + loss_curl

# Helper to generate random collocation points
def get_collocation_points(n_points=2000, bounds=(-1, 1)):
    # Generate random (x,y,z) points within the scaled domain
    return (bounds[1] - bounds[0]) * torch.rand(n_points, 3) + bounds[0]

# %%
# training
epochs = 5000
lambda_physics = 0.05  # Weighting factor for physics loss

print("Starting PINN training...")
# current_orbit_data.append((X_raw, y_raw, X_train, y_train, X_val, y_val, input_scaler, output_scaler))
orbits_models_data = []
for i, orbit_data in enumerate(orbits_preproc_data):
    model = PINN()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion_data = nn.MSELoss()


    print(f"Training on Orbit: {orbits[i]}")

    X_train, y_train = orbit_data[0][2], orbit_data[0][3]

    loss_history = {'data': [], 'physics': []}

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()

        # --- A. Data Loss (Supervised) ---
        # Fit the actual spacecraft measurements
        pred_data = model(X_train)
        loss_data = criterion_data(pred_data, y_train)

        # --- B. Physics Loss (Unsupervised) ---
        # Enforce Maxwell's equations at random points in the domain
        x_phys = get_collocation_points(n_points=1000)
        loss_phys = physics_loss_function(model, x_phys)

        # --- C. Total Loss ---
        loss_total = loss_data + (lambda_physics * loss_phys)

        loss_total.backward()
        optimizer.step()

        loss_history['data'].append(loss_data.item())
        loss_history['physics'].append(loss_phys.item())

        if (epoch + 1) % 500 == 0:
            print(f"Orbit: {orbits[i]} | Epoch {epoch+1}/{epochs}: Data Loss={loss_data.item():.5f} | Physics Loss={loss_phys.item():.5f}")

    orbits_models_data.append((copy.deepcopy(model.state_dict()), loss_history))
# Out:
# Starting PINN training...
# Training on Orbit: ORB04
# Orbit: ORB04 | Epoch 500/5000: Data Loss=0.01729 | Physics Loss=0.11246
# Orbit: ORB04 | Epoch 1000/5000: Data Loss=0.01152 | Physics Loss=0.09855
# Orbit: ORB04 | Epoch 1500/5000: Data Loss=0.00914 | Physics Loss=0.07299
# Orbit: ORB04 | Epoch 2000/5000: Data Loss=0.00839 | Physics Loss=0.06802
# Orbit: ORB04 | Epoch 2500/5000: Data Loss=0.00814 | Physics Loss=0.08408
# Orbit: ORB04 | Epoch 3000/5000: Data Loss=0.00779 | Physics Loss=0.07592
# Orbit: ORB04 | Epoch 3500/5000: Data Loss=0.00738 | Physics Loss=0.08106
# Orbit: ORB04 | Epoch 4000/5000: Data Loss=0.00749 | Physics Loss=0.05671
# Orbit: ORB04 | Epoch 4500/5000: Data Loss=0.00734 | Physics Loss=0.05518
# Orbit: ORB04 | Epoch 5000/5000: Data Loss=0.00729 | Physics Loss=0.04521
# Training on Orbit: ORB11
# Orbit: ORB11 | Epoch 500/5000: Data Loss=0.02280 | Physics Loss=0.04079
# Orbit: ORB11 | Epoch 1000/5000: Data Loss=0.02081 | Physics Loss=0.02477
# Orbit: ORB11 | Epoch 1500/5000: Data Loss=0.01989 | Physics Loss=0.02013
# Orbit: ORB11 | Epoch 2000/5000: Data Loss=0.01764 | Physics Loss=0.03601
# Orbit: ORB11 | Epoch 2500/5000: Data Loss=0.01564 | Physics Loss=0.05082
# Orbit: ORB11 | Epoch 3000/5000: Data Loss=0.01454 | Physics Loss=0.03664
# Orbit: ORB11 | Epoch 3500/5000: Data Loss=0.01363 | Physics Loss=0.07742
# Orbit: ORB11 | Epoch 4000/5000: Data Loss=0.01310 | Physics Loss=0.03711
# Orbit: ORB11 | Epoch 4500/5000: Data Loss=0.01258 | Physics Loss=0.03534
# Orbit: ORB11 | Epoch 5000/5000: Data Loss=0.01245 | Physics Loss=0.05330
# Training on Orbit: ORB12
# Orbit: ORB12 | Epoch 500/5000: Data Loss=0.02031 | Physics Loss=0.15007
# Orbit: ORB12 | Epoch 1000/5000: Data Loss=0.01184 | Physics Loss=0.12238
# Orbit: ORB12 | Epoch 1500/5000: Data Loss=0.01090 | Physics Loss=0.13610
# Orbit: ORB12 | Epoch 2000/5000: Data Loss=0.01061 | Physics Loss=0.09729
# Orbit: ORB12 | Epoch 2500/5000: Data Loss=0.00946 | Physics Loss=0.10405
# Orbit: ORB12 | Epoch 3000/5000: Data Loss=0.00968 | Physics Loss=0.05494
# Orbit: ORB12 | Epoch 3500/5000: Data Loss=0.00919 | Physics Loss=0.15669
# Orbit: ORB12 | Epoch 4000/5000: Data Loss=0.00933 | Physics Loss=0.04158
# Orbit: ORB12 | Epoch 4500/5000: Data Loss=0.00891 | Physics Loss=0.03694
# Orbit: ORB12 | Epoch 5000/5000: Data Loss=0.00860 | Physics Loss=0.04703
# Training on Orbit: ORB14
# Orbit: ORB14 | Epoch 500/5000: Data Loss=0.01534 | Physics Loss=0.31777
# Orbit: ORB14 | Epoch 1000/5000: Data Loss=0.00766 | Physics Loss=0.22549
# Orbit: ORB14 | Epoch 1500/5000: Data Loss=0.00525 | Physics Loss=0.16163
# Orbit: ORB14 | Epoch 2000/5000: Data Loss=0.00458 | Physics Loss=0.15179
# Orbit: ORB14 | Epoch 2500/5000: Data Loss=0.00393 | Physics Loss=0.11555
# Orbit: ORB14 | Epoch 3000/5000: Data Loss=0.00372 | Physics Loss=0.10887
# Orbit: ORB14 | Epoch 3500/5000: Data Loss=0.00379 | Physics Loss=0.07879
# Orbit: ORB14 | Epoch 4000/5000: Data Loss=0.00343 | Physics Loss=0.07685
# Orbit: ORB14 | Epoch 4500/5000: Data Loss=0.00338 | Physics Loss=0.14068
# Orbit: ORB14 | Epoch 5000/5000: Data Loss=0.00337 | Physics Loss=0.09034
# Training on Orbit: ORB19
# Orbit: ORB19 | Epoch 500/5000: Data Loss=0.00729 | Physics Loss=0.15051
# Orbit: ORB19 | Epoch 1000/5000: Data Loss=0.00423 | Physics Loss=0.09792
# Orbit: ORB19 | Epoch 1500/5000: Data Loss=0.00353 | Physics Loss=0.07906
# Orbit: ORB19 | Epoch 2000/5000: Data Loss=0.00313 | Physics Loss=0.07108
# Orbit: ORB19 | Epoch 2500/5000: Data Loss=0.00318 | Physics Loss=0.06617
# Orbit: ORB19 | Epoch 3000/5000: Data Loss=0.00310 | Physics Loss=0.03293
# Orbit: ORB19 | Epoch 3500/5000: Data Loss=0.00304 | Physics Loss=0.04767
# Orbit: ORB19 | Epoch 4000/5000: Data Loss=0.00293 | Physics Loss=0.03953
# Orbit: ORB19 | Epoch 4500/5000: Data Loss=0.00275 | Physics Loss=0.05927
# Orbit: ORB19 | Epoch 5000/5000: Data Loss=0.00291 | Physics Loss=0.03065
# Training on Orbit: ORB26
# Orbit: ORB26 | Epoch 500/5000: Data Loss=0.02831 | Physics Loss=0.02916
# Orbit: ORB26 | Epoch 1000/5000: Data Loss=0.02514 | Physics Loss=0.03563
# Orbit: ORB26 | Epoch 1500/5000: Data Loss=0.01165 | Physics Loss=0.10812
# Orbit: ORB26 | Epoch 2000/5000: Data Loss=0.00542 | Physics Loss=0.07786
# Orbit: ORB26 | Epoch 2500/5000: Data Loss=0.00373 | Physics Loss=0.12164
# Orbit: ORB26 | Epoch 3000/5000: Data Loss=0.00397 | Physics Loss=0.03098
# Orbit: ORB26 | Epoch 3500/5000: Data Loss=0.00542 | Physics Loss=0.02526
# Orbit: ORB26 | Epoch 4000/5000: Data Loss=0.00336 | Physics Loss=0.02107
# Orbit: ORB26 | Epoch 4500/5000: Data Loss=0.00267 | Physics Loss=0.01570
# Orbit: ORB26 | Epoch 5000/5000: Data Loss=0.00311 | Physics Loss=0.09744

# %%
# ... (Previous code remains the same up to the loop) ...

# results

for i, (orbit_packet, model_packet) in enumerate(zip(orbits_preproc_data, orbits_models_data)):

    # FIX 2: Unpack correctly.
    # orbit_packet is a list containing 1 tuple: [(X_raw, y_raw...)]
    # We need to grab that first element [0]
    model = PINN()

    # Unpack Data
    data_tuple = orbit_packet[0]
    X_raw, y_raw, X_train, y_train, X_val, y_val, input_scaler, output_scaler = data_tuple

    # Unpack Model Weights
    model_state, loss_history = model_packet

    # Load weights into the fresh model
    model.load_state_dict(model_state)
    model.eval() # Set to evaluation mode

    # --- Visualization ---
    plt.figure(figsize=(12, 5))

    # Loss Plot
    plt.subplot(1, 2, 1)
    plt.plot(loss_history['data'], label='Data Loss (MSE)')
    plt.plot(loss_history['physics'], label='Physics Loss (Maxwell)')
    plt.yscale('log')
    plt.grid(which="Major", linestyle='--', linewidth=0.5)
    plt.title(f'PINN Training Dynamics - {orbits[i]}')
    plt.xlabel('Epochs')
    plt.legend()

    # Prediction Plot
    model.eval()
    with torch.no_grad():
        X_scaled_current = input_scaler.transform(X_raw)
        X_tensor_current = torch.tensor(X_scaled_current, dtype=torch.float32)

        full_pred_scaled = model(X_tensor_current)
        full_pred = output_scaler.inverse_transform(full_pred_scaled.numpy())

    plt.subplot(1, 2, 2)
    plt.plot(y_raw[:, 2], 'k-', alpha=0.5, label='Actual BZ')
    plt.plot(full_pred[:, 2], 'r--', alpha=0.8, label='PINN Prediction')
    plt.grid(which="Major", linestyle='--', linewidth=0.5)
    plt.grid(which="Minor", linestyle=':', linewidth=0.5)
    plt.title(f'Reconstruction (BZ) - {orbits[i]}')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'pinn_results_{orbits[i]}_phys_lambda005.png') # Save with unique name
    plt.show()

    # Save model
    torch.save(model.state_dict(), f'europa_pinn_model_{orbits[i]}.pth')
    print(f"PINN Model for {orbits[i]} saved.")
# Out:
# PINN Model for ORB04 saved.
# PINN Model for ORB11 saved.
# PINN Model for ORB12 saved.
# PINN Model for ORB14 saved.
# PINN Model for ORB19 saved.
# PINN Model for ORB26 saved.

# %% [markdown]
# 1. Conversion of results into data about salinity and ocean depth
# 2. Separate model for plasma
# 3. JUICE Callisto and Ganymede data in 2031
# 4. Better Europa data in 2030
# 5. Comparison of Numerical and PINN approach
